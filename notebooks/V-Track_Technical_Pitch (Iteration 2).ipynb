# %% [markdown]
# # Group 2 V-Track: Technical Pitch
# > Members:
# > - Shantanu Dixit - 8965610
# > - Serageldin Monir Farid Abdelghaffar Abdelmoaty - 9052380
# > - Tai Siang Huang - 9006413
# > - Jaiminiben Natvarbhai Rathod - 8941937
# > - Mohammed Adeen Shaik - 8969152
# ---
#
# ## Washington DC Stop Data
# The dataset from https://catalog.data.gov/dataset/stop-data-b6fdf contains stop data from the Metropolitan Police Department (MPD) in Washington, D.C., covering vehicle, pedestrian, bicycle, and harbor stops from January 1, 2023, to June 30, 2024. It includes details such as stop location, reason, duration, and outcomes (e.g., tickets, searches, arrests), with data reflecting updates from the NEAR Act and a new records management system since August 2021.

# %% [markdown]
# ### Introduction of V-TRACK
#
# Objective: Optimize average stop time from 15 minutes to under 10 minutes.
#
# Dataset Size: 279,936 total records (2019–2022).
#
# Focus Subset: 127,939 stops involving observed moving violations with tickets.
#
# Data Source: Washington DC Metropolitan Police Department – Data.gov Stop Data.
#
# Target Variable: STOP_DURATION (in minutes).
#
# Key Features Used: GENDER, ETHNICITY, AGE, TICKET_COUNT, HOUR, SEARCH_FLAG, etc.
#
# Other Datasets :
# 1) San fransisco Dataset:  https://data.sfgov.org/Public-Safety/Police-Department-Stop-Data/ubqf-aqzw/about_data
# 2) San diego Dataset: https://data.sandiego.gov/datasets/police-ripa-stops/
# 3) California Dataset: https://openjustice.doj.ca.gov/data

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Load the Liberary

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import shapiro

# %% [markdown]
# ### Load the Dataset

# %%
# Load your dataset
df = pd.read_csv("./datasets/Stop_Data_2019_to_2022.csv")  # Use your file path if needed

# Show first few rows
df.head()
# Out:
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\1652492941.py:2: DtypeWarning: Columns (7,26,30,35,38,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./datasets/Stop_Data_2019_to_2022.csv")  # Use your file path if needed
#                                       CCN_ANONYMIZED        STOP_TYPE  \
# 0  df8eab5aa9c8055c8ec149204d376beeb422e182bbbb71...  Non-ticket Stop
# 1  364201002193313ae4b99e8455517ec24ce28a63d5446d...  Non-ticket Stop
# 2  367f1304e9ac5c4bb5bbd42fc75091ec689f5a45cbc385...  Non-ticket Stop
# 3  c25fb89c2c556d230540a574de9b48e7ba2317f584a55d...  Non-ticket Stop
# 4  c25fb89c2c556d230540a574de9b48e7ba2317f584a55d...  Non-ticket Stop
#
#                  DATETIME                                      STOP_LOCATION  \
# 0  2021/12/29 13:00:00+00       300 BLOCK OF 33RD DC, DC 20019 UNITED STATES
# 1  2021/12/29 13:48:00+00                                                NaN
# 2  2021/12/29 15:07:00+00  3700 BLOCK OF MINNESOTA AVENUE NE WASHINGTON, ...
# 3  2021/12/29 15:00:00+00  4100 BLOCK OF 1ST DC, WASHINGTON 20032 UNITED ...
# 4  2021/12/29 15:00:00+00  4100 BLOCK OF 1ST DC, WASHINGTON 20032 UNITED ...
#
#    STOP_DISTRICT  STOP_DURATION_MINS STOP_REASON_NONTICKET STOP_REASON_HARBOR  \
# 0            6.0                30.0      Call for service                NaN
# 1            4.0                 7.0      Call for service                NaN
# 2            6.0                 3.0      Call for service                NaN
# 3            NaN                30.0      Call for service                NaN
# 4            NaN                30.0      Call for service                NaN
#
#   STOP_REASON_TICKET  PERSON_SEARCH_PAT_DOWN  ...  BICYCLE_PMD  PEDESTRIAN  \
# 0                NaN                       0  ...            0           0
# 1                NaN                       0  ...            0           0
# 2                NaN                       0  ...            0           0
# 3                NaN                       1  ...            0           0
# 4                NaN                       0  ...            0           0
#
#    HARBOR  INVESTIGATIVE  TRAFFIC_INVOLVED  GIS_ID  CREATED  EDITED  OBJECTID  \
# 0       0              1                 0     NaN      NaN     NaN    280321
# 1       0              1                 0     NaN      NaN     NaN    280322
# 2       0              1                 0     NaN      NaN     NaN    280323
# 3       0              1                 0     NaN      NaN     NaN    280324
# 4       0              1                 0     NaN      NaN     NaN    280325
#
#                                  GLOBALID
# 0  {96FB2C7A-1B0A-45F2-9A65-0B900CD8E87A}
# 1  {C0F1EC59-8B26-4618-86B0-3A0C480DB33E}
# 2  {0BB100B4-A06A-467C-91FC-95558659796A}
# 3  {570F50DD-47E4-4CF6-803E-AB82753B9CE1}
# 4  {EF316A0F-77C9-4710-923A-DFA41CDA546F}
#
# [5 rows x 61 columns]

# %%
# Overview of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 279936 entries, 0 to 279935
# Data columns (total 61 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CCN_ANONYMIZED              118088 non-null  object
#  1   STOP_TYPE                   279936 non-null  object
#  2   DATETIME                    279936 non-null  object
#  3   STOP_LOCATION               277744 non-null  object
#  4   STOP_DISTRICT               277450 non-null  float64
#  5   STOP_DURATION_MINS          277305 non-null  float64
#  6   STOP_REASON_NONTICKET       118070 non-null  object
#  7   STOP_REASON_HARBOR          1111 non-null    object
#  8   STOP_REASON_TICKET          163036 non-null  object
#  9   PERSON_SEARCH_PAT_DOWN      279936 non-null  int64
#  10  PROPERTY_SEARCH_PAT_DOWN    279936 non-null  int64
#  11  PERSON_SEARCH_CONSENT       279936 non-null  int64
#  12  PERSON_SEARCH_PROB_CAUSE    279936 non-null  int64
#  13  PERSON_PROT_PAT_DOWN        279936 non-null  int64
#  14  PERSON_SEARCH_WARRANT       279936 non-null  int64
#  15  PROPERTY_SEARCH_CONSENT     279936 non-null  int64
#  16  PROPERTY_SEARCH_PROB_CAUSE  279936 non-null  int64
#  17  PROPERTY_PROT_PAT_DOWN      279936 non-null  int64
#  18  PROPERTY_SEARCH_WARRANT     279936 non-null  int64
#  19  PERSON_SEARCH_REA_CONSENT   5121 non-null    object
#  20  PERSON_SRCH_PROB_CAUSE      6794 non-null    object
#  21  PERSON_PAT_DOWN_REASON      15017 non-null   object
#  22  PERSON_SRCH_REASON_WARRANT  2230 non-null    object
#  23  PROP_SRCH_REASON_CONSENT    3715 non-null    object
#  24  PROP_SRCH_PROB_CAUSE        4077 non-null    object
#  25  PROP_PAT_DOWN_REASON        1399 non-null    object
#  26  PROP_SRCH_REASON_WARRANT    1040 non-null    object
#  27  PROPERTY_SRCH_OBJ_CONSENT   3715 non-null    object
#  28  PROP_SRCH_OBJ_PROB_CAUSE    4077 non-null    object
#  29  PROP_PAT_DOWN_OBJ           1399 non-null    object
#  30  PROP_SRCH_OBJ_WARRANT       1040 non-null    object
#  31  PERSON_SRCH_OBJ_SEIZED_CON  4593 non-null    object
#  32  PERSON_SRCH_OBJ_PROB_CAUSE  5922 non-null    object
#  33  PER_PRO_PAT_DOWN_OBJ_SEIZE  11416 non-null   object
#  34  PERSON_SRCH_OBJ_SEIZED_WAR  1856 non-null    object
#  35  PROP_SRCH_OBJ_SEIZE_CON     3006 non-null    object
#  36  PROP_SRCH_OBJ_SEIZE_CAUSE   3440 non-null    object
#  37  PROP_PAT_DOWN_OBJ_SEIZED    1076 non-null    object
#  38  PROP_SEARCH_OBJ_WARRANT     1000 non-null    object
#  39  TICKETS_ISSUED              113826 non-null  object
#  40  WARNINGS_ISSUED             62099 non-null   object
#  41  VOIDED_TICKETS              2739 non-null    object
#  42  TICKET_COUNT                279936 non-null  int64
#  43  WARNING_COUNT               279936 non-null  int64
#  44  VOID_COUNT                  279936 non-null  int64
#  45  ARREST_CHARGES              64172 non-null   object
#  46  GENDER                      279936 non-null  object
#  47  ETHNICITY                   278171 non-null  object
#  48  AGE                         272790 non-null  object
#  49  ARREST_DATE                 64186 non-null   object
#  50  VEHICLE                     279936 non-null  int64
#  51  BICYCLE_PMD                 279936 non-null  int64
#  52  PEDESTRIAN                  279936 non-null  int64
#  53  HARBOR                      279936 non-null  int64
#  54  INVESTIGATIVE               279936 non-null  int64
#  55  TRAFFIC_INVOLVED            279936 non-null  int64
#  56  GIS_ID                      0 non-null       float64
#  57  CREATED                     0 non-null       float64
#  58  EDITED                      0 non-null       float64
#  59  OBJECTID                    279936 non-null  int64
#  60  GLOBALID                    279936 non-null  object
# dtypes: float64(5), int64(20), object(36)
# memory usage: 130.3+ MB

# %%
# we need to convert this string to lower case to avoid duplicates
df['STOP_REASON_TICKET'] = df['STOP_REASON_TICKET'].str.lower()
df.STOP_REASON_TICKET.value_counts().head(10)
# Out:
# STOP_REASON_TICKET
# observed moving violation                                    127939
# observed equipment violation                                  15294
# calls for service                                             10021
# response to crash                                              8812
# bolo/lookout                                                    322
# info. obtained from le sources                                  281
# self-initiated: suspicion of a non-traffic crim. activity       210
# observed a weapon                                                71
# observed equipment violation; observed moving violation          18
# observed moving violation; observed equipment violation          14
# Name: count, dtype: int64

# %% [markdown]
# ### Formatting

# %%
df['STOP_REASON_TICKET'] = df['STOP_REASON_TICKET'].str.lower()
# filter out only the ticketed stops for observed moving violations
df_ticketed = df[df['STOP_REASON_TICKET'].str.contains('observed moving violation', na=False)]
df_ticketed.drop(columns=['STOP_REASON_TICKET','STOP_TYPE','STOP_REASON_NONTICKET','STOP_REASON_HARBOR'], inplace=True)
# Out:
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\613338637.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed.drop(columns=['STOP_REASON_TICKET','STOP_TYPE','STOP_REASON_NONTICKET','STOP_REASON_HARBOR'], inplace=True)

# %%
# Standardize column names
df_ticketed.columns = df_ticketed.columns.str.upper().str.strip()
# Rename the actual column for clarity and consistency
df_ticketed.rename(columns={"STOP_DURATION_MINS": "STOP_DURATION"}, inplace=True)
# Convert STOP_DISTRICT to numeric (force non-numeric to NaN)
df_ticketed['STOP_DISTRICT'] = pd.to_numeric(df_ticketed['STOP_DISTRICT'], errors='coerce')
# let's create columns for time of day from DATETIME
df_ticketed['DATETIME'] = pd.to_datetime(df_ticketed['DATETIME'], errors='coerce')

df_ticketed['HOUR'] = df_ticketed['DATETIME'].dt.hour
df_ticketed['MINUTE'] = df_ticketed['DATETIME'].dt.minute
df_ticketed['TIME_OF_DAY'] = df_ticketed['HOUR'] + df_ticketed['MINUTE']/60

df_ticketed.shape
# Out:
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\783864364.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed.rename(columns={"STOP_DURATION_MINS": "STOP_DURATION"}, inplace=True)
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\783864364.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed['STOP_DISTRICT'] = pd.to_numeric(df_ticketed['STOP_DISTRICT'], errors='coerce')
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\783864364.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed['DATETIME'] = pd.to_datetime(df_ticketed['DATETIME'], errors='coerce')
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\783864364.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed['HOUR'] = df_ticketed['DATETIME'].dt.hour
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\783864364.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed['MINUTE'] = df_ticketed['DATETIME'].dt.minute
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\783864364.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed['TIME_OF_DAY'] = df_ticketed['HOUR'] + df_ticketed['MINUTE']/60
# (127985, 60)

# %%
df_ticketed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 127985 entries, 43 to 279935
# Data columns (total 60 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CCN_ANONYMIZED              3135 non-null    object
#  1   DATETIME                    127985 non-null  datetime64[ns, UTC]
#  2   STOP_LOCATION               127976 non-null  object
#  3   STOP_DISTRICT               126998 non-null  float64
#  4   STOP_DURATION               127750 non-null  float64
#  5   PERSON_SEARCH_PAT_DOWN      127985 non-null  int64
#  6   PROPERTY_SEARCH_PAT_DOWN    127985 non-null  int64
#  7   PERSON_SEARCH_CONSENT       127985 non-null  int64
#  8   PERSON_SEARCH_PROB_CAUSE    127985 non-null  int64
#  9   PERSON_PROT_PAT_DOWN        127985 non-null  int64
#  10  PERSON_SEARCH_WARRANT       127985 non-null  int64
#  11  PROPERTY_SEARCH_CONSENT     127985 non-null  int64
#  12  PROPERTY_SEARCH_PROB_CAUSE  127985 non-null  int64
#  13  PROPERTY_PROT_PAT_DOWN      127985 non-null  int64
#  14  PROPERTY_SEARCH_WARRANT     127985 non-null  int64
#  15  PERSON_SEARCH_REA_CONSENT   217 non-null     object
#  16  PERSON_SRCH_PROB_CAUSE      87 non-null      object
#  17  PERSON_PAT_DOWN_REASON      241 non-null     object
#  18  PERSON_SRCH_REASON_WARRANT  2 non-null       object
#  19  PROP_SRCH_REASON_CONSENT    226 non-null     object
#  20  PROP_SRCH_PROB_CAUSE        140 non-null     object
#  21  PROP_PAT_DOWN_REASON        20 non-null      object
#  22  PROP_SRCH_REASON_WARRANT    0 non-null       object
#  23  PROPERTY_SRCH_OBJ_CONSENT   226 non-null     object
#  24  PROP_SRCH_OBJ_PROB_CAUSE    140 non-null     object
#  25  PROP_PAT_DOWN_OBJ           20 non-null      object
#  26  PROP_SRCH_OBJ_WARRANT       0 non-null       object
#  27  PERSON_SRCH_OBJ_SEIZED_CON  217 non-null     object
#  28  PERSON_SRCH_OBJ_PROB_CAUSE  87 non-null      object
#  29  PER_PRO_PAT_DOWN_OBJ_SEIZE  241 non-null     object
#  30  PERSON_SRCH_OBJ_SEIZED_WAR  2 non-null       object
#  31  PROP_SRCH_OBJ_SEIZE_CON     226 non-null     object
#  32  PROP_SRCH_OBJ_SEIZE_CAUSE   140 non-null     object
#  33  PROP_PAT_DOWN_OBJ_SEIZED    20 non-null      object
#  34  PROP_SEARCH_OBJ_WARRANT     0 non-null       object
#  35  TICKETS_ISSUED              83956 non-null   object
#  36  WARNINGS_ISSUED             52332 non-null   object
#  37  VOIDED_TICKETS              1907 non-null    object
#  38  TICKET_COUNT                127985 non-null  int64
#  39  WARNING_COUNT               127985 non-null  int64
#  40  VOID_COUNT                  127985 non-null  int64
#  41  ARREST_CHARGES              2625 non-null    object
#  42  GENDER                      127985 non-null  object
#  43  ETHNICITY                   126978 non-null  object
#  44  AGE                         127382 non-null  object
#  45  ARREST_DATE                 2626 non-null    object
#  46  VEHICLE                     127985 non-null  int64
#  47  BICYCLE_PMD                 127985 non-null  int64
#  48  PEDESTRIAN                  127985 non-null  int64
#  49  HARBOR                      127985 non-null  int64
#  50  INVESTIGATIVE               127985 non-null  int64
#  51  TRAFFIC_INVOLVED            127985 non-null  int64
#  52  GIS_ID                      0 non-null       float64
#  53  CREATED                     0 non-null       float64
#  54  EDITED                      0 non-null       float64
#  55  OBJECTID                    127985 non-null  int64
#  56  GLOBALID                    127985 non-null  object
#  57  HOUR                        127985 non-null  int32
#  58  MINUTE                      127985 non-null  int32
#  59  TIME_OF_DAY                 127985 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(6), int32(2), int64(20), object(31)
# memory usage: 58.6+ MB

# %% [markdown]
# ### Drop Columns

# %%
cols_to_drop = [  
    'PERSON_SEARCH_REA_CONSENT', 'PERSON_SRCH_PROB_CAUSE', 'PERSON_PAT_DOWN_REASON',
    'PERSON_SRCH_REASON_WARRANT', 'PROP_SRCH_REASON_CONSENT', 'PROP_SRCH_PROB_CAUSE',
    'PROP_PAT_DOWN_REASON', 'PROP_SRCH_REASON_WARRANT', 'PROPERTY_SRCH_OBJ_CONSENT',
    'PROP_SRCH_OBJ_PROB_CAUSE', 'PROP_PAT_DOWN_OBJ', 'PROP_SRCH_OBJ_WARRANT',
    'PERSON_SRCH_OBJ_SEIZED_CON', 'PERSON_SRCH_OBJ_PROB_CAUSE', 'PER_PRO_PAT_DOWN_OBJ_SEIZE',
    'PERSON_SRCH_OBJ_SEIZED_WAR', 'PROP_SRCH_OBJ_SEIZE_CON', 'PROP_SRCH_OBJ_SEIZE_CAUSE',
    'PROP_PAT_DOWN_OBJ_SEIZED', 'PROP_SEARCH_OBJ_WARRANT',
    'VOIDED_TICKETS',
    'ARREST_CHARGES', 'ARREST_DATE',
    'GIS_ID', 'CREATED', 'EDITED', 'OBJECTID', 'GLOBALID'
]

df_ticketed.drop(columns=cols_to_drop, inplace=True)
# Out:
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\3885656027.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ticketed.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ### Missing values

# %%
# Check column names and missing values
print("Missing values:\n", df_ticketed.isnull().sum())
# Out:
# Missing values:
#  CCN_ANONYMIZED                124850
# DATETIME                           0
# STOP_LOCATION                      9
# STOP_DISTRICT                    987
# STOP_DURATION                    235
# PERSON_SEARCH_PAT_DOWN             0
# PROPERTY_SEARCH_PAT_DOWN           0
# PERSON_SEARCH_CONSENT              0
# PERSON_SEARCH_PROB_CAUSE           0
# PERSON_PROT_PAT_DOWN               0
# PERSON_SEARCH_WARRANT              0
# PROPERTY_SEARCH_CONSENT            0
# PROPERTY_SEARCH_PROB_CAUSE         0
# PROPERTY_PROT_PAT_DOWN             0
# PROPERTY_SEARCH_WARRANT            0
# TICKETS_ISSUED                 44029
# WARNINGS_ISSUED                75653
# TICKET_COUNT                       0
# WARNING_COUNT                      0
# VOID_COUNT                         0
# GENDER                             0
# ETHNICITY                       1007
# AGE                              603
# VEHICLE                            0
# BICYCLE_PMD                        0
# PEDESTRIAN                         0
# HARBOR                             0
# INVESTIGATIVE                      0
# TRAFFIC_INVOLVED                   0
# HOUR                               0
# MINUTE                             0
# TIME_OF_DAY                        0
# dtype: int64

# %%
# check how many value of STOP_DURATION are negative or zero
negative_or_zero_count = df_ticketed[df_ticketed['STOP_DURATION'] <= 0].shape[0]
# check how many value of STOP_DURATION are over 1 day (1440 minutes)
over_one_day_count = df_ticketed[df_ticketed['STOP_DURATION'] > 1440].shape[0]

print(f"Negative or zero STOP_DURATION count: {negative_or_zero_count}")
print(f"STOP_DURATION over 1 day count: {over_one_day_count}")
# Out:
# Negative or zero STOP_DURATION count: 167
# STOP_DURATION over 1 day count: 0

# %% [markdown]
# ### Handle Missing Values

# %%
# Now perform cleaning on STOP_DURATION
df_ticketed = df_ticketed[df_ticketed['STOP_DURATION'] > 0]            # Remove negatives
df_ticketed = df_ticketed[df_ticketed['STOP_DURATION'] < 1440]         # Remove extreme outliers (more than 24 hours)

# Now fill missing values with the median
df_ticketed['STOP_DISTRICT'] = df_ticketed['STOP_DISTRICT'].fillna(df_ticketed['STOP_DISTRICT'].median())

# %% [markdown]
# - `CCN_ANONYMIZED` and `STOP_LOCATION_BLOCK` are acceptable to be empty

# %% [markdown]
# ### Distribution of STOP_DURATION

# %%
# Boxplot of STOP_DURATION without outliers
plt.figure(figsize=(12, 4))
sns.boxplot(x=df_ticketed['STOP_DURATION'], color='dodgerblue', showfliers=False)
median_value = df_ticketed['STOP_DURATION'].median()
mean_value = df_ticketed['STOP_DURATION'].mean()
plt.axvline(x=median_value, color='r', linestyle='--', label=f'Median ({median_value:.1f} minutes)')
plt.axvline(x=mean_value, color='g', linestyle='--', label=f'Mean ({mean_value:.1f} minutes)')
plt.title('Boxplot of STOP_DURATION')
plt.xlabel('Minutes')
plt.grid(True)
plt.legend()
plt.show()

# histogram of STOP_DURATION between 0 and 60 minutes
plt.figure(figsize=(12,4))
sns.histplot(df_ticketed[df_ticketed['STOP_DURATION'] <= 30]['STOP_DURATION'], bins=100, kde=True, color='dodgerblue')
plt.title('Distribution of STOP_DURATION (0 to 60 minutes)')
plt.xlabel('Minutes')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# Most stops are resolved within **5–20 minutes**.
#
# There's a heavy right tail, meaning a small number of cases take a much longer time.
#
# This skewness supports the case for optimizing outliers using AI-assisted tools, like your proposed RAG-based system.

# %% [markdown]
# ### CCN_ANONYMIZED with STOP_DURATION

# %%
#the column CCN_ANONYMIZED is a criminal cimplaint number, we can tell if a complaint was issued by checking if the value is not null
df_ticketed['CCN_ANONYMIZED'].notnull().value_counts()
# Out:
# CCN_ANONYMIZED
# False    124448
# True       3135
# Name: count, dtype: int64

# %% [markdown]
# This means that out of 127,939 cases, a total of 3135 cases were filed for complaints

# %%
#let's create a new column to indicate if a complaint was issued
df_ticketed['COMPLAINT_ISSUED'] = df_ticketed['CCN_ANONYMIZED'].notnull().astype(int)

#now we can drop the CCN_ANONYMIZED column
df_ticketed.drop(columns=['CCN_ANONYMIZED'], inplace=True)

# %%
# Group by COMPLAINT_ISSUED and calculate the mean stop duration
avg_stop_duration = df_ticketed.groupby('COMPLAINT_ISSUED')['STOP_DURATION'].mean().reset_index()
avg_stop_duration.columns = ['Complaint Issued', 'Average Stop Duration (minutes)']

#print the average stop duration for complaint issued vs not issued
print(avg_stop_duration)
# Out:
#    Complaint Issued  Average Stop Duration (minutes)
# 0                 0                         9.018160
# 1                 1                        20.016906

# %% [markdown]
# Now, this is a major finding.
#
# The average stop time for a raised complaint case is more than twice that of a non raised complaint

# %% [markdown]
# ### Distribution of Stops by 7 District

# %%
#convert stop district from float to categorical
df_ticketed['STOP_DISTRICT'] = df_ticketed['STOP_DISTRICT'].astype('category')

# %%
# Let's look at the distribution of stop districts
plt.figure(figsize=(12, 6))
sns.countplot(data=df_ticketed, x='STOP_DISTRICT', order=df_ticketed['STOP_DISTRICT'].value_counts().index)
plt.title('Distribution of Stops by District')
plt.xlabel('District')
plt.ylabel('Number of Stops')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Average Stop Duration by Time of Day

# %%
# let's look at average stop_duration_mins column by time of day, show labels for frequencies for every 6 hours(Morning, Afternoon, Evening, Night)
df_ticketed['TIME_OF_DAY'] = pd.cut(df_ticketed['TIME_OF_DAY'], bins=[0, 6, 12, 18, 24], labels=['Night', 'Morning', 'Afternoon', 'Evening'], right=False)

# Calculate average stop duration by time of day
avg_stop_duration = df_ticketed.groupby('TIME_OF_DAY')['STOP_DURATION'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='TIME_OF_DAY', y='STOP_DURATION', data=avg_stop_duration, palette='viridis')
plt.title('Average Stop Duration by Time of Day')
plt.xlabel('Time of Day')
plt.ylabel('Average Stop Duration (minutes)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\2844779979.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_stop_duration = df_ticketed.groupby('TIME_OF_DAY')['STOP_DURATION'].mean().reset_index()
# C:\Users\patti\AppData\Local\Temp\ipykernel_14564\2844779979.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TIME_OF_DAY', y='STOP_DURATION', data=avg_stop_duration, palette='viridis')

# %% [markdown]
# ### Invetigation Issued

# %%
# Group by INVESTIGATIVE and calculate the mean stop duration
avg_stop_duration_is = df_ticketed.groupby('INVESTIGATIVE')['STOP_DURATION'].mean().reset_index()
avg_stop_duration_is.columns = ['Invetigation Issued', 'Average Stop Duration (minutes)']

#print the average stop duration for complaint issued vs not issued
print(avg_stop_duration_is)
# Out:
#    Invetigation Issued  Average Stop Duration (minutes)
# 0                    0                         9.018160
# 1                    1                        20.016906

# %%
# Check for cases where investigative is True and complaint is not issued

investigative_no_complaint = df_ticketed[(df_ticketed['INVESTIGATIVE'] == True) & (df_ticketed['COMPLAINT_ISSUED'] == 0)]
print(f"Number of stops where investigative is True and complaint is not issued: {len(investigative_no_complaint)}")
# Out:
# Number of stops where investigative is True and complaint is not issued: 0

# %%
# checl for cases where investigative is False and complaint is issued
investigative_with_complaint = df_ticketed[(df_ticketed['INVESTIGATIVE'] == False) & (df_ticketed['COMPLAINT_ISSUED'] == 1)]
print(f"Number of stops where investigative is False and complaint is issued: {len(investigative_with_complaint)}")
# Out:
# Number of stops where investigative is False and complaint is issued: 0

# %%
df_ticketed=df_ticketed[df_ticketed["INVESTIGATIVE"]==True]

# %%
# check for cases where investigative is True and complaint is issued
investigative_with_complaint_issued = df_ticketed[(df_ticketed['INVESTIGATIVE'] == True) & (df_ticketed['COMPLAINT_ISSUED'] == 1)]
print(f"Number of stops where investigative is True and complaint is issued: {len(investigative_with_complaint_issued)}")
# Out:
# Number of stops where investigative is True and complaint is issued: 3135

# %% [markdown]
# ### Correlation Matrix of Numerical Columns

# %%
# Let's look for correlations between stop duration and other numerical columns
numerical_cols = df_ticketed.select_dtypes(include=[np.number]).columns.tolist()

# Calculate correlation matrix
correlation_matrix = df_ticketed[numerical_cols].corr()

# Plotting the correlation matrix
plt.figure(figsize=(20, 14))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix of Numerical Columns')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation with Stop Duration (Ticketed Only)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
corr = df_ticketed.corr(numeric_only=True)
sns.heatmap(
    corr[['STOP_DURATION']].sort_values(by='STOP_DURATION', ascending=False),
    annot=True, cmap='coolwarm'
)
plt.title("Correlation with Stop Duration (Ticketed Only)")
plt.show()

# %% [markdown]
# ### Stop Duration with others columns

# %%
sns.boxplot(data=df_ticketed, x='GENDER', y='STOP_DURATION')
plt.title("Stop Duration by Gender")
plt.show()

# %%
sns.boxplot(data=df_ticketed, x='ETHNICITY', y='STOP_DURATION')
plt.title("Stop Duration by Ethnicity")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=df_ticketed, x='TIME_OF_DAY', y='STOP_DURATION')
plt.title("Stop Duration by Time of Day")
plt.show()

# %% [markdown]
# ### Average Duration by Binary Search/Interaction Features

# %%
binary_cols = [
    'PERSON_SEARCH_PAT_DOWN', 'PERSON_SEARCH_CONSENT', 'PERSON_SEARCH_PROB_CAUSE',
    'PROPERTY_SEARCH_CONSENT', 'PROPERTY_SEARCH_PAT_DOWN', 'PROPERTY_SEARCH_PROB_CAUSE',
    'INVESTIGATIVE', 'PEDESTRIAN', 'BICYCLE_PMD'
]

for col in binary_cols:
    print(f"\nAvg Stop Duration by {col}:")
    print(df_ticketed.groupby(col)['STOP_DURATION'].mean())
# Out:
# Avg Stop Duration by PERSON_SEARCH_PAT_DOWN:
# PERSON_SEARCH_PAT_DOWN
# 0    19.913933
# 1    20.507353
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by PERSON_SEARCH_CONSENT:
# PERSON_SEARCH_CONSENT
# 0    20.208705
# 1    17.437788
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by PERSON_SEARCH_PROB_CAUSE:
# PERSON_SEARCH_PROB_CAUSE
# 0    19.922244
# 1    23.333333
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by PROPERTY_SEARCH_CONSENT:
# PROPERTY_SEARCH_CONSENT
# 0    20.188725
# 1    17.805310
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by PROPERTY_SEARCH_PAT_DOWN:
# PROPERTY_SEARCH_PAT_DOWN
# 0    19.866497
# 1    21.088083
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by PROPERTY_SEARCH_PROB_CAUSE:
# PROPERTY_SEARCH_PROB_CAUSE
# 0    19.677129
# 1    27.285714
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by INVESTIGATIVE:
# INVESTIGATIVE
# 1    20.016906
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by PEDESTRIAN:
# PEDESTRIAN
# 0    20.019808
# 1    18.200000
# Name: STOP_DURATION, dtype: float64
#
# Avg Stop Duration by BICYCLE_PMD:
# BICYCLE_PMD
# 0    20.013725
# 1    25.000000
# Name: STOP_DURATION, dtype: float64

# %% [markdown]
# ### EDA Summary
#
# - **Population:** Traffic stops recorded in [jurisdiction], anonymized case-by-case.
# - **Independent Variables:** STOP_TYPE, STOP_DISTRICT, DATETIME, STOP_LOCATION_BLOCK
# - **Dependent Variable:** STOP_DURATION (minutes)
# - **Current Mean Duration:** ~15 minutes
# - **Ideal Target:** < 10 minutes
# - **Investigation Issued:** The data also shows that the average time for Investigation and Complaint is about 20 minutes.
#
# ---
#
# ### Key EDA Insights
#
# - Most stops are completed in under 20 minutes.
# - Ticket-only stops have lower durations than others.
# - Weekdays see more stops, especially during working hours.
# - STOP_TYPE and STOP_DISTRICT are the strongest indicators for duration variation.
# - STOP_DURATION shows a right-skewed distribution.

# %% [markdown]
# ## Statistical Test and Evaluation
#
# - ~~**Null Hypothesis (H₀):** The RAG-based system has no significant effect on reducing traffic stop duration.~~
# - ~~**Alternative Hypothesis (H₁):** The RAG-based system significantly reduces the average traffic stop processing time.~~
#
# The columns (`STOP_DISTRICT`, `STOP_DURATION`, `TICKETS_ISSUED`, `WARNINGS_ISSUED`) are ideal for building RAG system observations. These columns can provide rich context and action basis for the system, especially for judicial support systems to optimize traffic stop processing time.
#
# - **Null Hypothesis (H₀):** The selected columns has no significant effect on traffic stop duration.
# - **Alternative Hypothesis (H₁):** The selected columns significantly effect on the average traffic stop processing time.

# %%
# Extract the stop durations, dropping missing values
stop_durations = df_ticketed['STOP_DURATION'].dropna()

# Quick summary
print("Sample size:", len(stop_durations))
print("Mean:", stop_durations.mean())
print("Median:", stop_durations.median())
print("Standard Deviation:", stop_durations.std())
# Out:
# Sample size: 3135
# Mean: 20.016905901116427
# Median: 19.0
# Standard Deviation: 13.327619143405391

# %% [markdown]
# ### Shapiro-Wilk Test for Normality

# %%
# Run the Shapiro-Wilk test
shapiro_stat, shapiro_p = shapiro(stop_durations)

print(f"Shapiro-Wilk Test:\nStatistic = {shapiro_stat:.4f}, p-value = {shapiro_p:.4f}")

if shapiro_p > 0.05:
    print("Data appears normally distributed — would proceed with t-test.")
else:
    print("Data is not normally distributed — proceed with non-parametric test.")
# Out:
# Shapiro-Wilk Test:
# Statistic = 0.8580, p-value = 0.0000
# Data is not normally distributed — proceed with non-parametric test.

# %% [markdown]
# - Shapiro-Wilk test yielded a test statistic of `0.8580` and a **p-value of < 0.0001**, which is far below the 0.05 significance threshold. Therefore, we reject the assumption of normality.
# - Given the sample size (N = 3,135), even small deviations from normality can lead to significant results.
# - Thus, a non-parametric test (**Kruskal-Wallis Test**) is more appropriate for comparing the median stop duration against the 10-minute benchmark.

# %% [markdown]
# ### Statistical methods
# - Category variables: <br>
#  The effect of different categories on `STOP_DURATION` was tested using the Kruskal-Wallis test.

# %%
from scipy.stats import kruskal
#Kruskal-Wallis test (categorical variables)
for col in ['STOP_DISTRICT']:
    groups = [df_ticketed[df_ticketed[col] == val]['STOP_DURATION'].dropna() for val in df_ticketed[col].unique()]
    stat, p = kruskal(*groups)
    print(f"\nKruskal-Wallis Test for {col}:")
    print(f"Statistic: {stat:.4f}, p-value: {p:.4f}")
    if p < 0.05:
        print(f"Reject H₀: {col} has a significant effect on STOP_DURATION.")
    else:
        print(f"Fail to reject H₀: No significant effect of {col}.")
# Out:
# Kruskal-Wallis Test for STOP_DISTRICT:
# Statistic: 244.0931, p-value: 0.0000
# Reject H₀: STOP_DISTRICT has a significant effect on STOP_DURATION.

# %%
print("Data types:")
print(df_ticketed[['TICKETS_ISSUED', 'WARNINGS_ISSUED']].dtypes)
# Out:
# Data types:
# TICKETS_ISSUED     object
# WARNINGS_ISSUED    object
# dtype: object

# %%
# Ensure the column exists and fill missing values
df_ticketed["TICKETS_ISSUED"] = df_ticketed["TICKETS_ISSUED"].fillna("").astype(str)

# Count number of tickets in each row
df_ticketed["TICKETS_COUNT"] = df_ticketed["TICKETS_ISSUED"].apply(lambda x: len([code.strip() for code in x.split(";") if code.strip()]))

# Summary
total_tickets = df_ticketed["TICKETS_COUNT"].sum()
max_tickets_in_row = df_ticketed["TICKETS_COUNT"].max()
ticket_count_distribution = df_ticketed["TICKETS_COUNT"].value_counts().sort_index()

# Output
print("Total TICKETS_ISSUED:", total_tickets)
print("Max Tickets in One Row:", max_tickets_in_row)
print("\nTicket Count Distribution per Row:\n", ticket_count_distribution)
# Out:
# Total TICKETS_ISSUED: 4277
# Max Tickets in One Row: 11
#
# Ticket Count Distribution per Row:
#  TICKETS_COUNT
# 0      686
# 1     1503
# 2      465
# 3      249
# 4      140
# 5       54
# 6       22
# 7        7
# 8        2
# 9        1
# 10       5
# 11       1
# Name: count, dtype: int64

# %%
# Define a function to split multi-value strings
def split_values(x):
    if pd.isna(x):
        return []
    return [val.strip() for val in str(x).split(';')]

# Apply to columns
df_ticketed['TICKETS_ISSUED_LIST'] = df_ticketed['TICKETS_ISSUED'].apply(split_values)
df_ticketed['WARNINGS_ISSUED_LIST'] = df_ticketed['WARNINGS_ISSUED'].apply(split_values)

# Check unique types
all_tickets = [item for sublist in df_ticketed['TICKETS_ISSUED_LIST'].dropna() for item in sublist]
all_warnings = [item for sublist in df_ticketed['WARNINGS_ISSUED_LIST'].dropna() for item in sublist]
print("Unique TICKETS_ISSUED types:", set(all_tickets))
print("Unique WARNINGS_ISSUED types:", set(all_warnings))
# Out:
# Unique TICKETS_ISSUED types: {'', 'T124', 'T945', 'T600', 'T676', 'T658', 'T343', 'T193', 'T107', 'T200', 'T779', 'T121', 'T555', 'T579', 'T118', 'T155', 'T050', 'T580', 'T630', 'T765', 'T673', 'T400', 'T659', 'T350', 'T068', 'T082', 'T217', 'T210', 'T120', 'T656', 'T805', 'T219', 'T117', 'T815', 'T640', 'T151', 'T671', 'T705', 'T113', 'T743', 'T711', 'T806', 'T940', 'T654', 'T106', 'T771', '392.2S', 'T184', 'T214', 'T207', 'T915', 'T192', 'T662', 'T938', 'T939', 'T048', 'T119', 'T404', 'T715', 'T227', 'T352', 'T013', 'T105', 'T109', 'T819', 'T112', 'T742', 'T766', 'T224', 'T668', 'T639', 'T539', 'T065', 'T605', 'T178', 'T216', 'T346', 'T713', 'T018', 'T278', 'T934', 'T590', 'T277', 'T768', 'T088', 'T687', 'T183', 'T008', 'T559', 'T637', 'T511', 'T523', 'T171', 'T347', 'T512', 'T666', 'T576', 'T760', 'T144', 'T334', 'T746', 'T185', 'T591', 'T011', 'T638', '383.23(c)', 'T758', 'T712', 'T749', 'T206', 'T150', 'T633', 'T181', 'T012', 'T108', 'T748', 'T335', 'T745', 'T299', 'T043', 'T036', 'T005', 'T115', 'T202', 'T266', 'T080', 'T051', 'T189', 'T936', 'T169', 'T813', 'T932', 'T670', 'T763', 'T201', 'T529', 'T759', 'T533', 'T039', 'T028', 'T125', 'T058', 'T634', 'T667', 'T127', 'T114', 'T822', 'T333', 'T059', 'T282', 'T744', 'T571', 'T710', 'T405', 'T702', 'T351', 'T057', 'T515', 'T674', 'T823', 'T116', 'T238', 'T128', 'T247', 'T122', 'T747', 'T632', 'T095', 'T218', 'T740', 'T205', 'T101', 'T672'}
# Unique WARNINGS_ISSUED types: {'T945', 'T067', 'T658', 'T107', 'T200', 'T751', 'T121', 'T118', 'T050', 'T630', 'T765', '392.16', 'T400', 'T673', 'T082', 'T120', 'T656', 'T219', 'T585', 'T640', 'T069', 'T151', 'T671', 'T113', 'T711', 'T049', 'T940', 'T654', 'T184', 'T915', 'T192', 'T939', 'T119', 'T647', 'T404', 'T715', 'T227', 'T013', 'T109', 'T742', 'T112', 'T577', 'T668', 'T626', 'T639', 'T539', 'T065', 'T178', 'T346', 'T216', 'T713', 'T018', 'T590', 'T183', 'T559', 'T637', 'T170', 'T666', 'T760', 'T562', 'T334', 'T746', 'T185', 'T591', 'T011', 'T638', 'T758', 'T528', 'T206', 'T401', 'T150', 'T181', 'T748', 'T335', 'T745', 'T299', 'T636', 'T005', 'T115', 'T202', 'T080', 'T051', 'T649', 'T670', 'T763', 'T533', 'T125', 'T058', 'T667', 'T135', 'T127', 'T653', 'T114', 'T822', 'T333', 'T059', 'T744', 'T674', 'T116', 'T128', 'T247', 'T122', 'T747', 'T218', 'T205', 'T101', 'T672'}

# %% [markdown]
# ### One-Hot Encoding

# %%
# Get all unique types (assuming 'TICKETS_ISSUED_LIST' and 'WARNINGS_ISSUED_LIST' are lists of strings per row)
all_tickets = [ticket for sublist in df_ticketed['TICKETS_ISSUED_LIST'] for ticket in sublist]
unique_tickets = set(all_tickets)

all_warnings = [warning for sublist in df_ticketed['WARNINGS_ISSUED_LIST'] for warning in sublist]
unique_warnings = set(all_warnings)

# Create a list to hold new ticket columns as Series
new_ticket_columns = []
for ticket_type in unique_tickets:
    col_name = f'TICKET_{ticket_type.replace(" ", "_").replace("(", "").replace(")", "")}'
    new_col = df_ticketed['TICKETS_ISSUED_LIST'].apply(lambda x: 1 if ticket_type in x else 0)
    new_col.name = col_name  # Set the column name
    new_ticket_columns.append(new_col)

# Create a list to hold new warning columns as Series
new_warning_columns = []
for warning_type in unique_warnings:
    col_name = f'WARNING_{warning_type.replace(" ", "_").replace("(", "").replace(")", "")}'
    new_col = df_ticketed['WARNINGS_ISSUED_LIST'].apply(lambda x: 1 if warning_type in x else 0)
    new_col.name = col_name  # Set the column name
    new_warning_columns.append(new_col)

# Concat all new columns at once to avoid fragmentation
new_columns_df = pd.concat(new_ticket_columns + new_warning_columns, axis=1)
df_ticketed = pd.concat([df_ticketed, new_columns_df], axis=1)

# Print new columns (for verification)
print("New columns created:", df_ticketed.filter(like='TICKET_').columns.tolist())
print("New columns created:", df_ticketed.filter(like='WARNING_').columns.tolist())
# Out:
# New columns created: ['TICKET_COUNT', 'TICKET_', 'TICKET_T124', 'TICKET_T945', 'TICKET_T600', 'TICKET_T676', 'TICKET_T658', 'TICKET_T343', 'TICKET_T193', 'TICKET_T107', 'TICKET_T200', 'TICKET_T779', 'TICKET_T121', 'TICKET_T555', 'TICKET_T579', 'TICKET_T118', 'TICKET_T155', 'TICKET_T050', 'TICKET_T580', 'TICKET_T630', 'TICKET_T765', 'TICKET_T673', 'TICKET_T400', 'TICKET_T659', 'TICKET_T350', 'TICKET_T068', 'TICKET_T082', 'TICKET_T217', 'TICKET_T210', 'TICKET_T120', 'TICKET_T656', 'TICKET_T805', 'TICKET_T219', 'TICKET_T117', 'TICKET_T815', 'TICKET_T640', 'TICKET_T151', 'TICKET_T671', 'TICKET_T705', 'TICKET_T113', 'TICKET_T743', 'TICKET_T711', 'TICKET_T806', 'TICKET_T940', 'TICKET_T654', 'TICKET_T106', 'TICKET_T771', 'TICKET_392.2S', 'TICKET_T184', 'TICKET_T214', 'TICKET_T207', 'TICKET_T915', 'TICKET_T192', 'TICKET_T662', 'TICKET_T938', 'TICKET_T939', 'TICKET_T048', 'TICKET_T119', 'TICKET_T404', 'TICKET_T715', 'TICKET_T227', 'TICKET_T352', 'TICKET_T013', 'TICKET_T105', 'TICKET_T109', 'TICKET_T819', 'TICKET_T112', 'TICKET_T742', 'TICKET_T766', 'TICKET_T224', 'TICKET_T668', 'TICKET_T639', 'TICKET_T539', 'TICKET_T065', 'TICKET_T605', 'TICKET_T178', 'TICKET_T216', 'TICKET_T346', 'TICKET_T713', 'TICKET_T018', 'TICKET_T278', 'TICKET_T934', 'TICKET_T590', 'TICKET_T277', 'TICKET_T768', 'TICKET_T088', 'TICKET_T687', 'TICKET_T183', 'TICKET_T008', 'TICKET_T559', 'TICKET_T637', 'TICKET_T511', 'TICKET_T523', 'TICKET_T171', 'TICKET_T347', 'TICKET_T512', 'TICKET_T666', 'TICKET_T576', 'TICKET_T760', 'TICKET_T144', 'TICKET_T334', 'TICKET_T746', 'TICKET_T185', 'TICKET_T591', 'TICKET_T011', 'TICKET_T638', 'TICKET_383.23c', 'TICKET_T758', 'TICKET_T712', 'TICKET_T749', 'TICKET_T206', 'TICKET_T150', 'TICKET_T633', 'TICKET_T181', 'TICKET_T012', 'TICKET_T108', 'TICKET_T748', 'TICKET_T335', 'TICKET_T745', 'TICKET_T299', 'TICKET_T043', 'TICKET_T036', 'TICKET_T005', 'TICKET_T115', 'TICKET_T202', 'TICKET_T266', 'TICKET_T080', 'TICKET_T051', 'TICKET_T189', 'TICKET_T936', 'TICKET_T169', 'TICKET_T813', 'TICKET_T932', 'TICKET_T670', 'TICKET_T763', 'TICKET_T201', 'TICKET_T529', 'TICKET_T759', 'TICKET_T533', 'TICKET_T039', 'TICKET_T028', 'TICKET_T125', 'TICKET_T058', 'TICKET_T634', 'TICKET_T667', 'TICKET_T127', 'TICKET_T114', 'TICKET_T822', 'TICKET_T333', 'TICKET_T059', 'TICKET_T282', 'TICKET_T744', 'TICKET_T571', 'TICKET_T710', 'TICKET_T405', 'TICKET_T702', 'TICKET_T351', 'TICKET_T057', 'TICKET_T515', 'TICKET_T674', 'TICKET_T823', 'TICKET_T116', 'TICKET_T238', 'TICKET_T128', 'TICKET_T247', 'TICKET_T122', 'TICKET_T747', 'TICKET_T632', 'TICKET_T095', 'TICKET_T218', 'TICKET_T740', 'TICKET_T205', 'TICKET_T101', 'TICKET_T672']
# New columns created: ['WARNING_COUNT', 'WARNING_T945', 'WARNING_T067', 'WARNING_T658', 'WARNING_T107', 'WARNING_T200', 'WARNING_T751', 'WARNING_T121', 'WARNING_T118', 'WARNING_T050', 'WARNING_T630', 'WARNING_T765', 'WARNING_392.16', 'WARNING_T400', 'WARNING_T673', 'WARNING_T082', 'WARNING_T120', 'WARNING_T656', 'WARNING_T219', 'WARNING_T585', 'WARNING_T640', 'WARNING_T069', 'WARNING_T151', 'WARNING_T671', 'WARNING_T113', 'WARNING_T711', 'WARNING_T049', 'WARNING_T940', 'WARNING_T654', 'WARNING_T184', 'WARNING_T915', 'WARNING_T192', 'WARNING_T939', 'WARNING_T119', 'WARNING_T647', 'WARNING_T404', 'WARNING_T715', 'WARNING_T227', 'WARNING_T013', 'WARNING_T109', 'WARNING_T742', 'WARNING_T112', 'WARNING_T577', 'WARNING_T668', 'WARNING_T626', 'WARNING_T639', 'WARNING_T539', 'WARNING_T065', 'WARNING_T178', 'WARNING_T346', 'WARNING_T216', 'WARNING_T713', 'WARNING_T018', 'WARNING_T590', 'WARNING_T183', 'WARNING_T559', 'WARNING_T637', 'WARNING_T170', 'WARNING_T666', 'WARNING_T760', 'WARNING_T562', 'WARNING_T334', 'WARNING_T746', 'WARNING_T185', 'WARNING_T591', 'WARNING_T011', 'WARNING_T638', 'WARNING_T758', 'WARNING_T528', 'WARNING_T206', 'WARNING_T401', 'WARNING_T150', 'WARNING_T181', 'WARNING_T748', 'WARNING_T335', 'WARNING_T745', 'WARNING_T299', 'WARNING_T636', 'WARNING_T005', 'WARNING_T115', 'WARNING_T202', 'WARNING_T080', 'WARNING_T051', 'WARNING_T649', 'WARNING_T670', 'WARNING_T763', 'WARNING_T533', 'WARNING_T125', 'WARNING_T058', 'WARNING_T667', 'WARNING_T135', 'WARNING_T127', 'WARNING_T653', 'WARNING_T114', 'WARNING_T822', 'WARNING_T333', 'WARNING_T059', 'WARNING_T744', 'WARNING_T674', 'WARNING_T116', 'WARNING_T128', 'WARNING_T247', 'WARNING_T122', 'WARNING_T747', 'WARNING_T218', 'WARNING_T205', 'WARNING_T101', 'WARNING_T672']

# %% [markdown]
# ### Kruskal-Wallis test

# %%
from scipy.stats import kruskal

# Store columns with significant and non-significant effects
significant_effects = []
non_significant_effects = []

# Perform Kruskal-Wallis test for each ticket type column
for col in df_ticketed.filter(like='TICKET_').columns:
    group_with = df_ticketed[df_ticketed[col] == 1]['STOP_DURATION'].dropna()
    group_without = df_ticketed[df_ticketed[col] == 0]['STOP_DURATION'].dropna()
    if len(group_with) > 0 and len(group_without) > 0:
        stat, p = kruskal(group_with, group_without)
        print(f"\nKruskal-Wallis Test for {col}:")
        print(f"Statistic: {stat:.4f}, p-value: {p:.4f}")
        if p < 0.05:
            print(f"Reject H₀: {col} has a significant effect on STOP_DURATION.")
            significant_effects.append(col)
        else:
            print(f"Fail to reject H₀: No significant effect.")
            non_significant_effects.append(col)
# Out:
# Kruskal-Wallis Test for TICKET_COUNT:
# Statistic: 6.8381, p-value: 0.0089
# Reject H₀: TICKET_COUNT has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_:
# Statistic: 9.6672, p-value: 0.0019
# Reject H₀: TICKET_ has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T124:
# Statistic: 0.0328, p-value: 0.8563
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T945:
# Statistic: 2.8006, p-value: 0.0942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T600:
# Statistic: 1.5268, p-value: 0.2166
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T676:
# Statistic: 0.0441, p-value: 0.8337
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T658:
# Statistic: 50.5197, p-value: 0.0000
# Reject H₀: TICKET_T658 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T343:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T193:
# Statistic: 0.3339, p-value: 0.5634
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T107:
# Statistic: 5.1394, p-value: 0.0234
# Reject H₀: TICKET_T107 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T200:
# Statistic: 5.5107, p-value: 0.0189
# Reject H₀: TICKET_T200 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T779:
# Statistic: 0.3741, p-value: 0.5408
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T121:
# Statistic: 0.2113, p-value: 0.6458
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T555:
# Statistic: 2.1637, p-value: 0.1413
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T579:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T118:
# Statistic: 0.2534, p-value: 0.6147
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T155:
# Statistic: 3.7228, p-value: 0.0537
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T050:
# Statistic: 0.0141, p-value: 0.9053
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T580:
# Statistic: 2.5490, p-value: 0.1104
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T630:
# Statistic: 0.9717, p-value: 0.3243
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T765:
# Statistic: 4.4208, p-value: 0.0355
# Reject H₀: TICKET_T765 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T673:
# Statistic: 4.5093, p-value: 0.0337
# Reject H₀: TICKET_T673 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T400:
# Statistic: 2.5536, p-value: 0.1100
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T659:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T350:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T068:
# Statistic: 0.9440, p-value: 0.3313
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T082:
# Statistic: 1.4968, p-value: 0.2212
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T217:
# Statistic: 0.9440, p-value: 0.3313
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T210:
# Statistic: 1.2203, p-value: 0.2693
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T120:
# Statistic: 0.2500, p-value: 0.6170
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T656:
# Statistic: 0.6200, p-value: 0.4311
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T805:
# Statistic: 1.6512, p-value: 0.1988
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T219:
# Statistic: 0.3339, p-value: 0.5634
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T117:
# Statistic: 0.0191, p-value: 0.8902
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T815:
# Statistic: 0.0919, p-value: 0.7617
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T640:
# Statistic: 0.0380, p-value: 0.8455
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T151:
# Statistic: 0.1473, p-value: 0.7011
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T671:
# Statistic: 1.5210, p-value: 0.2175
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T705:
# Statistic: 1.0089, p-value: 0.3152
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T113:
# Statistic: 21.9083, p-value: 0.0000
# Reject H₀: TICKET_T113 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T743:
# Statistic: 0.2168, p-value: 0.6415
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T711:
# Statistic: 24.1119, p-value: 0.0000
# Reject H₀: TICKET_T711 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T806:
# Statistic: 0.5607, p-value: 0.4540
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T940:
# Statistic: 0.5550, p-value: 0.4563
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T654:
# Statistic: 0.4213, p-value: 0.5163
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T106:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T771:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_392.2S:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T184:
# Statistic: 0.0127, p-value: 0.9103
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T214:
# Statistic: 0.9440, p-value: 0.3313
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T207:
# Statistic: 0.8714, p-value: 0.3506
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T915:
# Statistic: 0.0826, p-value: 0.7738
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T192:
# Statistic: 6.2053, p-value: 0.0127
# Reject H₀: TICKET_T192 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T662:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T938:
# Statistic: 0.0655, p-value: 0.7979
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T939:
# Statistic: 4.1715, p-value: 0.0411
# Reject H₀: TICKET_T939 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T048:
# Statistic: 1.5431, p-value: 0.2141
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T119:
# Statistic: 2.0542, p-value: 0.1518
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T404:
# Statistic: 16.0611, p-value: 0.0001
# Reject H₀: TICKET_T404 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T715:
# Statistic: 0.0408, p-value: 0.8399
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T227:
# Statistic: 41.8239, p-value: 0.0000
# Reject H₀: TICKET_T227 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T352:
# Statistic: 0.2931, p-value: 0.5883
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T013:
# Statistic: 17.6448, p-value: 0.0000
# Reject H₀: TICKET_T013 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T105:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T109:
# Statistic: 0.0533, p-value: 0.8175
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T819:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T112:
# Statistic: 30.9323, p-value: 0.0000
# Reject H₀: TICKET_T112 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T742:
# Statistic: 60.3177, p-value: 0.0000
# Reject H₀: TICKET_T742 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T766:
# Statistic: 0.0317, p-value: 0.8587
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T224:
# Statistic: 2.5728, p-value: 0.1087
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T668:
# Statistic: 5.5113, p-value: 0.0189
# Reject H₀: TICKET_T668 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T639:
# Statistic: 2.4917, p-value: 0.1145
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T539:
# Statistic: 2.1118, p-value: 0.1462
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T065:
# Statistic: 3.6937, p-value: 0.0546
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T605:
# Statistic: 2.5026, p-value: 0.1137
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T178:
# Statistic: 3.3191, p-value: 0.0685
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T216:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T346:
# Statistic: 6.2525, p-value: 0.0124
# Reject H₀: TICKET_T346 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T713:
# Statistic: 0.1380, p-value: 0.7103
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T018:
# Statistic: 4.6706, p-value: 0.0307
# Reject H₀: TICKET_T018 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T278:
# Statistic: 0.2533, p-value: 0.6148
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T934:
# Statistic: 2.7343, p-value: 0.0982
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T590:
# Statistic: 2.6941, p-value: 0.1007
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T277:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T768:
# Statistic: 0.0006, p-value: 0.9804
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T088:
# Statistic: 1.3362, p-value: 0.2477
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T687:
# Statistic: 2.6361, p-value: 0.1045
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T183:
# Statistic: 1.6199, p-value: 0.2031
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T008:
# Statistic: 0.5607, p-value: 0.4540
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T559:
# Statistic: 0.0697, p-value: 0.7918
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T637:
# Statistic: 1.2575, p-value: 0.2621
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T511:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T523:
# Statistic: 0.3741, p-value: 0.5408
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T171:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T347:
# Statistic: 2.6197, p-value: 0.1055
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T512:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T666:
# Statistic: 0.2201, p-value: 0.6390
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T576:
# Statistic: 2.3984, p-value: 0.1215
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T760:
# Statistic: 0.6445, p-value: 0.4221
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T144:
# Statistic: 1.7497, p-value: 0.1859
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T334:
# Statistic: 0.0091, p-value: 0.9238
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T746:
# Statistic: 3.7049, p-value: 0.0543
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T185:
# Statistic: 0.5766, p-value: 0.4477
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T591:
# Statistic: 0.0577, p-value: 0.8102
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T011:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T638:
# Statistic: 3.1257, p-value: 0.0771
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_383.23c:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T758:
# Statistic: 0.0005, p-value: 0.9828
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T712:
# Statistic: 2.4691, p-value: 0.1161
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T749:
# Statistic: 1.1799, p-value: 0.2774
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T206:
# Statistic: 0.3678, p-value: 0.5442
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T150:
# Statistic: 0.6891, p-value: 0.4065
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T633:
# Statistic: 3.0709, p-value: 0.0797
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T181:
# Statistic: 0.9047, p-value: 0.3415
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T012:
# Statistic: 1.7705, p-value: 0.1833
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T108:
# Statistic: 3.3883, p-value: 0.0657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T748:
# Statistic: 10.9355, p-value: 0.0009
# Reject H₀: TICKET_T748 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T335:
# Statistic: 1.6704, p-value: 0.1962
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T745:
# Statistic: 6.7054, p-value: 0.0096
# Reject H₀: TICKET_T745 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T299:
# Statistic: 0.4074, p-value: 0.5233
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T043:
# Statistic: 1.5232, p-value: 0.2171
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T036:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T005:
# Statistic: 0.3468, p-value: 0.5559
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T115:
# Statistic: 13.7983, p-value: 0.0002
# Reject H₀: TICKET_T115 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T202:
# Statistic: 2.4596, p-value: 0.1168
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T266:
# Statistic: 2.5065, p-value: 0.1134
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T080:
# Statistic: 0.0313, p-value: 0.8595
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T051:
# Statistic: 3.9717, p-value: 0.0463
# Reject H₀: TICKET_T051 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T189:
# Statistic: 0.5607, p-value: 0.4540
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T936:
# Statistic: 0.1240, p-value: 0.7247
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T169:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T813:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T932:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T670:
# Statistic: 2.5335, p-value: 0.1115
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T763:
# Statistic: 0.2953, p-value: 0.5869
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T201:
# Statistic: 1.5048, p-value: 0.2199
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T529:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T759:
# Statistic: 0.3023, p-value: 0.5825
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T533:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T039:
# Statistic: 2.1637, p-value: 0.1413
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T028:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T125:
# Statistic: 3.2797, p-value: 0.0701
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T058:
# Statistic: 15.9565, p-value: 0.0001
# Reject H₀: TICKET_T058 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T634:
# Statistic: 2.9862, p-value: 0.0840
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T667:
# Statistic: 5.4089, p-value: 0.0200
# Reject H₀: TICKET_T667 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T127:
# Statistic: 1.3742, p-value: 0.2411
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T114:
# Statistic: 0.8920, p-value: 0.3449
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T822:
# Statistic: 1.4366, p-value: 0.2307
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T333:
# Statistic: 20.7644, p-value: 0.0000
# Reject H₀: TICKET_T333 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T059:
# Statistic: 3.3793, p-value: 0.0660
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T282:
# Statistic: 2.2196, p-value: 0.1363
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T744:
# Statistic: 0.1471, p-value: 0.7013
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T571:
# Statistic: 7.8041, p-value: 0.0052
# Reject H₀: TICKET_T571 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T710:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T405:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T702:
# Statistic: 0.0038, p-value: 0.9512
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T351:
# Statistic: 2.0429, p-value: 0.1529
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T057:
# Statistic: 0.0337, p-value: 0.8543
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T515:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T674:
# Statistic: 0.2661, p-value: 0.6060
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T823:
# Statistic: 21.2632, p-value: 0.0000
# Reject H₀: TICKET_T823 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T116:
# Statistic: 4.5322, p-value: 0.0333
# Reject H₀: TICKET_T116 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for TICKET_T238:
# Statistic: 2.5026, p-value: 0.1137
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T128:
# Statistic: 3.1466, p-value: 0.0761
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T247:
# Statistic: 1.8052, p-value: 0.1791
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T122:
# Statistic: 3.2379, p-value: 0.0720
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T747:
# Statistic: 1.4840, p-value: 0.2232
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T632:
# Statistic: 0.6010, p-value: 0.4382
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T095:
# Statistic: 0.0914, p-value: 0.7624
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T218:
# Statistic: 0.0567, p-value: 0.8117
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T740:
# Statistic: 0.7917, p-value: 0.3736
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T205:
# Statistic: 0.2691, p-value: 0.6040
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T101:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for TICKET_T672:
# Statistic: 0.8516, p-value: 0.3561
# Fail to reject H₀: No significant effect.

# %%
# Total results
print("\nSummary of Significant Effects:")
if significant_effects:
    print("Columns with significant effect:", significant_effects)
else:
    print("No columns have a significant effect on STOP_DURATION.")

print("\nSummary of Non-Significant Effects:")
if non_significant_effects:
    print("Columns with no significant effect:", non_significant_effects)
else:
    print("No columns have a non-significant effect (all are significant).")
# Out:
# Summary of Significant Effects:
# Columns with significant effect: ['TICKET_COUNT', 'TICKET_', 'TICKET_T658', 'TICKET_T107', 'TICKET_T200', 'TICKET_T765', 'TICKET_T673', 'TICKET_T113', 'TICKET_T711', 'TICKET_T192', 'TICKET_T939', 'TICKET_T404', 'TICKET_T227', 'TICKET_T013', 'TICKET_T112', 'TICKET_T742', 'TICKET_T668', 'TICKET_T346', 'TICKET_T018', 'TICKET_T748', 'TICKET_T745', 'TICKET_T115', 'TICKET_T051', 'TICKET_T058', 'TICKET_T667', 'TICKET_T333', 'TICKET_T571', 'TICKET_T823', 'TICKET_T116']
#
# Summary of Non-Significant Effects:
# Columns with no significant effect: ['TICKET_T124', 'TICKET_T945', 'TICKET_T600', 'TICKET_T676', 'TICKET_T343', 'TICKET_T193', 'TICKET_T779', 'TICKET_T121', 'TICKET_T555', 'TICKET_T579', 'TICKET_T118', 'TICKET_T155', 'TICKET_T050', 'TICKET_T580', 'TICKET_T630', 'TICKET_T400', 'TICKET_T659', 'TICKET_T350', 'TICKET_T068', 'TICKET_T082', 'TICKET_T217', 'TICKET_T210', 'TICKET_T120', 'TICKET_T656', 'TICKET_T805', 'TICKET_T219', 'TICKET_T117', 'TICKET_T815', 'TICKET_T640', 'TICKET_T151', 'TICKET_T671', 'TICKET_T705', 'TICKET_T743', 'TICKET_T806', 'TICKET_T940', 'TICKET_T654', 'TICKET_T106', 'TICKET_T771', 'TICKET_392.2S', 'TICKET_T184', 'TICKET_T214', 'TICKET_T207', 'TICKET_T915', 'TICKET_T662', 'TICKET_T938', 'TICKET_T048', 'TICKET_T119', 'TICKET_T715', 'TICKET_T352', 'TICKET_T105', 'TICKET_T109', 'TICKET_T819', 'TICKET_T766', 'TICKET_T224', 'TICKET_T639', 'TICKET_T539', 'TICKET_T065', 'TICKET_T605', 'TICKET_T178', 'TICKET_T216', 'TICKET_T713', 'TICKET_T278', 'TICKET_T934', 'TICKET_T590', 'TICKET_T277', 'TICKET_T768', 'TICKET_T088', 'TICKET_T687', 'TICKET_T183', 'TICKET_T008', 'TICKET_T559', 'TICKET_T637', 'TICKET_T511', 'TICKET_T523', 'TICKET_T171', 'TICKET_T347', 'TICKET_T512', 'TICKET_T666', 'TICKET_T576', 'TICKET_T760', 'TICKET_T144', 'TICKET_T334', 'TICKET_T746', 'TICKET_T185', 'TICKET_T591', 'TICKET_T011', 'TICKET_T638', 'TICKET_383.23c', 'TICKET_T758', 'TICKET_T712', 'TICKET_T749', 'TICKET_T206', 'TICKET_T150', 'TICKET_T633', 'TICKET_T181', 'TICKET_T012', 'TICKET_T108', 'TICKET_T335', 'TICKET_T299', 'TICKET_T043', 'TICKET_T036', 'TICKET_T005', 'TICKET_T202', 'TICKET_T266', 'TICKET_T080', 'TICKET_T189', 'TICKET_T936', 'TICKET_T169', 'TICKET_T813', 'TICKET_T932', 'TICKET_T670', 'TICKET_T763', 'TICKET_T201', 'TICKET_T529', 'TICKET_T759', 'TICKET_T533', 'TICKET_T039', 'TICKET_T028', 'TICKET_T125', 'TICKET_T634', 'TICKET_T127', 'TICKET_T114', 'TICKET_T822', 'TICKET_T059', 'TICKET_T282', 'TICKET_T744', 'TICKET_T710', 'TICKET_T405', 'TICKET_T702', 'TICKET_T351', 'TICKET_T057', 'TICKET_T515', 'TICKET_T674', 'TICKET_T238', 'TICKET_T128', 'TICKET_T247', 'TICKET_T122', 'TICKET_T747', 'TICKET_T632', 'TICKET_T095', 'TICKET_T218', 'TICKET_T740', 'TICKET_T205', 'TICKET_T101', 'TICKET_T672']

# %%
# Store columns with significant and non-significant effects
significant_effects_warnings = []
non_significant_effects_warnings = []

# Perform Kruskal-Wallis test
for col in df_ticketed.filter(like='WARNING_').columns:
    group_with = df_ticketed[df_ticketed[col] == 1]['STOP_DURATION'].dropna()
    group_without = df_ticketed[df_ticketed[col] == 0]['STOP_DURATION'].dropna()
    if len(group_with) > 0 and len(group_without) > 0:
        stat, p = kruskal(group_with, group_without)
        print(f"\nKruskal-Wallis Test for {col}:")
        print(f"Statistic: {stat:.4f}, p-value: {p:.4f}")
        if p < 0.05:
            print(f"Reject H₀: {col} has a significant effect on STOP_DURATION.")
            significant_effects_warnings.append(col)
        else:
            print(f"Fail to reject H₀: No significant effect.")
            non_significant_effects_warnings.append(col)
# Out:
# Kruskal-Wallis Test for WARNING_COUNT:
# Statistic: 8.0154, p-value: 0.0046
# Reject H₀: WARNING_COUNT has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T945:
# Statistic: 0.3627, p-value: 0.5470
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T067:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T658:
# Statistic: 0.8835, p-value: 0.3472
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T107:
# Statistic: 5.0524, p-value: 0.0246
# Reject H₀: WARNING_T107 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T200:
# Statistic: 0.0496, p-value: 0.8238
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T751:
# Statistic: 0.5607, p-value: 0.4540
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T121:
# Statistic: 0.1362, p-value: 0.7121
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T118:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T050:
# Statistic: 0.0124, p-value: 0.9113
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T630:
# Statistic: 0.0002, p-value: 0.9894
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T765:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_392.16:
# Statistic: 0.8092, p-value: 0.3684
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T400:
# Statistic: 0.9178, p-value: 0.3381
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T673:
# Statistic: 0.0705, p-value: 0.7907
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T082:
# Statistic: 0.6467, p-value: 0.4213
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T120:
# Statistic: 0.0031, p-value: 0.9553
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T656:
# Statistic: 0.2533, p-value: 0.6148
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T219:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T585:
# Statistic: 0.0031, p-value: 0.9553
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T640:
# Statistic: 2.2196, p-value: 0.1363
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T069:
# Statistic: 0.2533, p-value: 0.6148
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T151:
# Statistic: 0.2020, p-value: 0.6531
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T671:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T113:
# Statistic: 3.5187, p-value: 0.0607
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T711:
# Statistic: 0.9182, p-value: 0.3380
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T049:
# Statistic: 0.7203, p-value: 0.3960
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T940:
# Statistic: 0.0648, p-value: 0.7990
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T654:
# Statistic: 0.2533, p-value: 0.6148
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T184:
# Statistic: 0.1481, p-value: 0.7003
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T915:
# Statistic: 2.6298, p-value: 0.1049
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T192:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T939:
# Statistic: 0.0226, p-value: 0.8804
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T119:
# Statistic: 2.1667, p-value: 0.1410
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T647:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T404:
# Statistic: 0.0557, p-value: 0.8134
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T715:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T227:
# Statistic: 0.0010, p-value: 0.9754
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T013:
# Statistic: 0.1124, p-value: 0.7375
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T109:
# Statistic: 1.5723, p-value: 0.2099
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T742:
# Statistic: 0.4340, p-value: 0.5100
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T112:
# Statistic: 0.5580, p-value: 0.4551
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T577:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T668:
# Statistic: 5.2607, p-value: 0.0218
# Reject H₀: WARNING_T668 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T626:
# Statistic: 2.4780, p-value: 0.1154
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T639:
# Statistic: 0.5942, p-value: 0.4408
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T539:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T065:
# Statistic: 0.3718, p-value: 0.5420
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T178:
# Statistic: 0.3310, p-value: 0.5651
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T346:
# Statistic: 0.0121, p-value: 0.9125
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T216:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T713:
# Statistic: 0.0494, p-value: 0.8241
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T018:
# Statistic: 0.5528, p-value: 0.4572
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T590:
# Statistic: 0.0103, p-value: 0.9193
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T183:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T559:
# Statistic: 0.0914, p-value: 0.7624
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T637:
# Statistic: 0.1083, p-value: 0.7421
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T170:
# Statistic: 1.6512, p-value: 0.1988
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T666:
# Statistic: 0.5607, p-value: 0.4540
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T760:
# Statistic: 0.0031, p-value: 0.9553
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T562:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T334:
# Statistic: 0.9440, p-value: 0.3313
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T746:
# Statistic: 0.4773, p-value: 0.4897
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T185:
# Statistic: 0.0253, p-value: 0.8735
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T591:
# Statistic: 0.0004, p-value: 0.9833
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T011:
# Statistic: 1.4074, p-value: 0.2355
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T638:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T758:
# Statistic: 0.4269, p-value: 0.5135
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T528:
# Statistic: 2.1637, p-value: 0.1413
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T206:
# Statistic: 1.6512, p-value: 0.1988
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T401:
# Statistic: 2.6397, p-value: 0.1042
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T150:
# Statistic: 2.4793, p-value: 0.1154
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T181:
# Statistic: 0.8506, p-value: 0.3564
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T748:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T335:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T745:
# Statistic: 1.6804, p-value: 0.1949
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T299:
# Statistic: 0.0681, p-value: 0.7942
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T636:
# Statistic: 0.3339, p-value: 0.5634
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T005:
# Statistic: 2.0595, p-value: 0.1513
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T115:
# Statistic: 4.1180, p-value: 0.0424
# Reject H₀: WARNING_T115 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T202:
# Statistic: 0.0324, p-value: 0.8572
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T080:
# Statistic: 4.1343, p-value: 0.0420
# Reject H₀: WARNING_T080 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T051:
# Statistic: 2.1637, p-value: 0.1413
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T649:
# Statistic: 0.3824, p-value: 0.5363
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T670:
# Statistic: 0.3513, p-value: 0.5534
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T763:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T533:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T125:
# Statistic: 0.8989, p-value: 0.3431
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T058:
# Statistic: 6.2440, p-value: 0.0125
# Reject H₀: WARNING_T058 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T667:
# Statistic: 1.7597, p-value: 0.1847
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T135:
# Statistic: 0.9458, p-value: 0.3308
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T127:
# Statistic: 0.1180, p-value: 0.7312
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T653:
# Statistic: 0.1207, p-value: 0.7282
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T114:
# Statistic: 0.3824, p-value: 0.5363
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T822:
# Statistic: 0.4225, p-value: 0.5157
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T333:
# Statistic: 0.0579, p-value: 0.8098
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T059:
# Statistic: 0.2816, p-value: 0.5956
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T744:
# Statistic: 0.2931, p-value: 0.5883
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T674:
# Statistic: 0.3057, p-value: 0.5804
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T116:
# Statistic: 0.4303, p-value: 0.5118
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T128:
# Statistic: 5.0952, p-value: 0.0240
# Reject H₀: WARNING_T128 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T247:
# Statistic: 5.2780, p-value: 0.0216
# Reject H₀: WARNING_T247 has a significant effect on STOP_DURATION.
#
# Kruskal-Wallis Test for WARNING_T122:
# Statistic: 1.4694, p-value: 0.2254
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T747:
# Statistic: 3.0161, p-value: 0.0824
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T218:
# Statistic: 2.5930, p-value: 0.1073
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T205:
# Statistic: 2.0208, p-value: 0.1552
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T101:
# Statistic: 1.2386, p-value: 0.2657
# Fail to reject H₀: No significant effect.
#
# Kruskal-Wallis Test for WARNING_T672:
# Statistic: 0.0177, p-value: 0.8942
# Fail to reject H₀: No significant effect.

# %%
print("\nSummary of Significant Effects:")
if significant_effects_warnings:
    print("Columns with significant effect:", significant_effects_warnings)
else:
    print("No columns have a significant effect on STOP_DURATION.")

print("\nSummary of Non-Significant Effects:")
if non_significant_effects_warnings:
    print("Columns with no significant effect:", non_significant_effects_warnings)
else:
    print("No columns have a non-significant effect (all are significant).")
# Out:
# Summary of Significant Effects:
# Columns with significant effect: ['WARNING_COUNT', 'WARNING_T107', 'WARNING_T668', 'WARNING_T115', 'WARNING_T080', 'WARNING_T058', 'WARNING_T128', 'WARNING_T247']
#
# Summary of Non-Significant Effects:
# Columns with no significant effect: ['WARNING_T945', 'WARNING_T067', 'WARNING_T658', 'WARNING_T200', 'WARNING_T751', 'WARNING_T121', 'WARNING_T118', 'WARNING_T050', 'WARNING_T630', 'WARNING_T765', 'WARNING_392.16', 'WARNING_T400', 'WARNING_T673', 'WARNING_T082', 'WARNING_T120', 'WARNING_T656', 'WARNING_T219', 'WARNING_T585', 'WARNING_T640', 'WARNING_T069', 'WARNING_T151', 'WARNING_T671', 'WARNING_T113', 'WARNING_T711', 'WARNING_T049', 'WARNING_T940', 'WARNING_T654', 'WARNING_T184', 'WARNING_T915', 'WARNING_T192', 'WARNING_T939', 'WARNING_T119', 'WARNING_T647', 'WARNING_T404', 'WARNING_T715', 'WARNING_T227', 'WARNING_T013', 'WARNING_T109', 'WARNING_T742', 'WARNING_T112', 'WARNING_T577', 'WARNING_T626', 'WARNING_T639', 'WARNING_T539', 'WARNING_T065', 'WARNING_T178', 'WARNING_T346', 'WARNING_T216', 'WARNING_T713', 'WARNING_T018', 'WARNING_T590', 'WARNING_T183', 'WARNING_T559', 'WARNING_T637', 'WARNING_T170', 'WARNING_T666', 'WARNING_T760', 'WARNING_T562', 'WARNING_T334', 'WARNING_T746', 'WARNING_T185', 'WARNING_T591', 'WARNING_T011', 'WARNING_T638', 'WARNING_T758', 'WARNING_T528', 'WARNING_T206', 'WARNING_T401', 'WARNING_T150', 'WARNING_T181', 'WARNING_T748', 'WARNING_T335', 'WARNING_T745', 'WARNING_T299', 'WARNING_T636', 'WARNING_T005', 'WARNING_T202', 'WARNING_T051', 'WARNING_T649', 'WARNING_T670', 'WARNING_T763', 'WARNING_T533', 'WARNING_T125', 'WARNING_T667', 'WARNING_T135', 'WARNING_T127', 'WARNING_T653', 'WARNING_T114', 'WARNING_T822', 'WARNING_T333', 'WARNING_T059', 'WARNING_T744', 'WARNING_T674', 'WARNING_T116', 'WARNING_T122', 'WARNING_T747', 'WARNING_T218', 'WARNING_T205', 'WARNING_T101', 'WARNING_T672']

# %% [markdown]
# ### Evaluation
# - Reject **Null Hypothesis (H₀)**, `STOP_DISTRICT`, some of `TICKETS_ISSUED`, some of `WARNINGS_ISSUED` have a significant effect on `STOP_DURATION`

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder
import pandas as pd

df_model = df_ticketed.copy()

# Encode categorical columns
le_gender = LabelEncoder()
le_ethnicity = LabelEncoder()

df_model['GENDER'] = le_gender.fit_transform(df_model['GENDER'])
df_model['ETHNICITY'] = le_ethnicity.fit_transform(df_model['ETHNICITY'])
df_model['AGE'] = pd.to_numeric(df_model['AGE'], errors='coerce')

features = [
    'GENDER', 'ETHNICITY', 'AGE', 'VEHICLE', 'PEDESTRIAN', 'BICYCLE_PMD',
    'PERSON_SEARCH_PAT_DOWN', 'PERSON_SEARCH_CONSENT', 'PERSON_SEARCH_PROB_CAUSE',
    'PROPERTY_SEARCH_CONSENT', 'PROPERTY_SEARCH_PAT_DOWN',
    'TICKET_COUNT', 'WARNING_COUNT', 'INVESTIGATIVE', 'HOUR',
    # 'STOP_DISTRICT'
]

# insert significant_effects and significant_effects_warnings
# features += significant_effects + significant_effects_warnings

X = df_model[features]
y = df_model['STOP_DURATION']

model = DecisionTreeRegressor(max_depth=4, random_state=42)
model.fit(X, y)

# Feature importance
importances = pd.Series(model.feature_importances_, index=features)
importances.sort_values().plot(kind='barh', figsize=(10, 10), title='Feature Importance: Stop Duration')
plt.xlabel("Importance Score")
plt.show()

# %%
# feature importance printed in a table format
importances_df = importances.reset_index()
importances_df.columns = ['Feature', 'Importance']
print(importances_df.sort_values(by='Importance', ascending=False).to_string(index=False))
# Out:
#                  Feature  Importance
#                     HOUR    0.364287
#             TICKET_COUNT    0.345604
#            WARNING_COUNT    0.076965
#                      AGE    0.070026
#  PROPERTY_SEARCH_CONSENT    0.061056
# PERSON_SEARCH_PROB_CAUSE    0.046156
#                   GENDER    0.035906
#   PERSON_SEARCH_PAT_DOWN    0.000000
#              BICYCLE_PMD    0.000000
#               PEDESTRIAN    0.000000
#                  VEHICLE    0.000000
#                ETHNICITY    0.000000
#    PERSON_SEARCH_CONSENT    0.000000
# PROPERTY_SEARCH_PAT_DOWN    0.000000
#            INVESTIGATIVE    0.000000

# %%
long_stops = df_ticketed[df_ticketed['STOP_DURATION'] > 30]
print(f"{len(long_stops)} stops exceed 30 minutes")
display(long_stops[['DATETIME', 'STOP_LOCATION', 'STOP_DURATION']].sort_values(by='STOP_DURATION', ascending=False).head())
# Out:
# 431 stops exceed 30 minutes
#                         DATETIME  \
# 35528  2021-06-22 18:50:00+00:00
# 64406  2021-01-23 08:22:00+00:00
# 48077  2021-04-19 18:53:00+00:00
# 175292 2019-10-19 00:20:00+00:00
# 167811 2019-11-07 13:12:00+00:00
#
#                                             STOP_LOCATION  STOP_DURATION
# 35528   4400 BLOCK OF TEXAS AVENUE SE WASHINGTON, DC 2...          215.0
# 64406   200 BLOCK OF NEW YORK AVENUE NW WASHINGTON, DC...          128.0
# 48077   3900 BLOCK OF BENNING ROAD NE WASHINGTON, DC 2...          120.0
# 175292  1700 BLOCK OF R STREET NW WASHINGTON, DC 20009...          120.0
# 167811  3300 BLOCK OF ERIE STREET SE WASHINGTON, DC 20...          104.0

# %% [markdown]
# ## ✅ Recommendations to Reduce Stop Duration
#
# ### 🔧 1. Optimize Ticket Writing (`TICKET_COUNT`)
# - Integrate **V-Track chatbot** to automate ticket suggestions and autofill forms.
# - Prioritize **standardized penalty templates** to reduce officer decision time.
#
# ### 🕒 2. Improve Operations Based on Time (`HOUR`)
# - Allocate **experienced officers** to late-night shifts.
# - Investigate **time-specific delays** (e.g., shift changes, server slowdowns).
#
# ### 📝 3. Simplify Warning Protocols (`WARNING_COUNT`)
# - Digitize and auto-fill **warning forms**.
# - Use **pre-scripted verbal explanations** for clarity and speed.
#
# ### 🎒 4. Streamline Consent-Based Searches
# - Train officers on **clear necessity thresholds**.
# - Use **digital consent logging** to avoid manual paperwork.
#
# ### 👥 5. Tailor Interactions by Age (`AGE`)
# - For very young or elderly drivers, consider using **simple language or visual aids**.
# - Minimize **unnecessary repetition** to avoid extended stop times.
